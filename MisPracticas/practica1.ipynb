# %%
print('Hola mundo desde sistemas inteligentes :3')
# Out:
# Hola mundo desde sistemas inteligentes :3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Todo funciona correctamente :D")
# Out:
# NumPy: 2.5.3
# Pandas: 3.0.5
# Scikit-learn: 1.9.0
# Todo funciona correctamente :D
